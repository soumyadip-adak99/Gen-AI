# %% [markdown]
# ## Data Types

# %% [markdown]
# ## Data types are classification of the data that tells the compiler or the interpreter that what kind of values we can store into a varibale and how much amount of memory will be consumed to store the data and the operations it can perform.

# %%
age=input("Enter your age:" )
print(type(age))
print(age)
# Out:
# <class 'str'>
# 4

# %%
age=int(input("Enter your age: "))
print(type(age))
print(age)
# Out:
# <class 'int'>
# 4
