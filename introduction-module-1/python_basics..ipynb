# %%
print("Hello world")
# Out:
# Hello world

# %%
age = int(input("Enter your age: "))
if age > 18:
    print(f"Age: {age}\nYou are eligible for driving.")
# Out:
# Age: 24
# You are eligible for driving.

# %% [markdown]
# Use semi-colone in python use for multiple code in single line

# %%
a = 10; b = 30; sum = a + b 
print(sum)
# Out:
# 40
