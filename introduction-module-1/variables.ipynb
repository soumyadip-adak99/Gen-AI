# %% [markdown]
# ## Variable

# %% [markdown]
# # Variables are the elements in python that can be used for stroing data into it or valeus into it or they can be referred as containers as well.
# ## varibales as per its name, data can vary that we are going to streo into it adn once we have decleard a variable we can vary the value stroed in it.

# %%
# variable is age 
age = 13 
# name also a variable it is a string value
name = "soumya"  

#streo the float value
hight = 8.2

# streo boolean value
is_true = True
