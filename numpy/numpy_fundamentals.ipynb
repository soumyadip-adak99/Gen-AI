# %% [markdown]
# # Numpy

# %% [markdown]
# Numpy is a Fundamental package for scientific computing in python.
# It is a python libary that provides Multi Dimanstional Array Object and various derived objets such as masked arrays
# or Matrices and an assortement of routines for fast operations on arrays including mathematical logical, shape manupulation
# sorting operation, selection, I/O, Discrete Furier Transformation, Basic Linear Algebra, Stastical Operations, Reandom Semulation, etc .
#
# ##### At the core of the Numpy Pacakge is the multidimensional array object.
