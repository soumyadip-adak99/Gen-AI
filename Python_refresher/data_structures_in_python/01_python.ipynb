# %% [markdown]
# ## Data Structures in Python

# %% [markdown]
# #### Data Structures in Python are being used for storing the data in a structured format so that we can access the data and along with that we can perform all of the orpereations with these data structures that we can perform in the case of databases as well like crud (create, read, update, delete) operations

# %% [markdown]
# ## Types of Data Structures
# 1. List
# 2. Tuple
# 3. Set
# 4. Dictionary
