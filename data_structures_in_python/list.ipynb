# %% [markdown]
# ## List

# %% [markdown]
# List are one of the types of the data structure which are used for stroing your data in a structured format where you can store data of any data types and that as it is one of the data structure so we can have access to the data as well that we are going to store into the list and we can apply crud operations as well i.e create, read, update, delete operations as well

# %%
arr = [1, 2, 3, 4]
print(arr)
# Out:
# [1, 2, 3, 4]

# %%
arr = [1, "hello world", 3.3]
print(type(arr))
print(arr)
# Out:
# <class 'list'>
# [1, 'hello world', 3.3]

# %%
a = list()
print(type(a))
# Out:
# <class 'list'>

# %%
list = ["mango", "apple", "banana", "guava", "grapes", "pineapple"]
print(list[4])
print(list[-1])
print(list[-6])
# Out:
# grapes
# pineapple
# mango
