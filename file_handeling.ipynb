# %% [markdown]
# ## File Handling

# %% [markdown]
# ## 1. Read the content from My Text file in the system

# %%
# opening file
open()

#

# %%
f = open('example.txt', 'r') # open file
content = f.read() # read() function for read the file
print(content)
